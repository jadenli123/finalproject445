# %% [markdown]
# """Dataset Info"""
#
# """ Name of dataset: Abalone Dataset from UCI
#
# Dataset link: https://www.kaggle.com/datasets/nayanack/abalone-dataset-from-uci
#
# Dataset download: https://www.kaggle.com/datasets/nayanack/abalone-dataset-from-uci/download?datasetVersionNumber=2
#
# License: This dataset is licensed under CC0: Public Domain
#
# This allows for the sharing and adaptation of the datasets for any purpose, a form of copyright that allows creators to waive legal interest in their work and move it into the public domain as far as possible.
#
# Size: abalone1.data is 192 KB
#
# """

# %% [markdown]
# """ Characteristics of this dataset:
#
# This dataset contains 4177 lines of information regarding different abalones with their respective traits such as sex, length, height, etc.
#
# """

# %%
import pandas as pd
import bqplot
import json
import pandas as pd 
import bqplot.pyplot as plt
import re
import numpy as np
import random
from functools import reduce
import seaborn as sns
from ast import literal_eval
# import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Downloads\archive\abalone1.data.txt", encoding='iso-8859-1', header=None,
                 names=['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 
                        'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings'])
df
# Out:
#       Sex   Length   Diameter   Height   Whole_weight   Shucked_weight  \
# 0     Sex   Length   Diameter   Height   Whole_weight   Shucked_weight
# 1       M    0.455      0.365    0.095          0.514           0.2245
# 2       M     0.35      0.265     0.09         0.2255           0.0995
# 3       F     0.53       0.42    0.135          0.677           0.2565
# 4       M     0.44      0.365    0.125          0.516           0.2155
# ...   ...      ...        ...      ...            ...              ...
# 4173    F    0.565       0.45    0.165          0.887             0.37
# 4174    M     0.59       0.44    0.135          0.966            0.439
# 4175    M      0.6      0.475    0.205          1.176           0.5255
# 4176    F    0.625      0.485     0.15         1.0945            0.531
# 4177    M     0.71      0.555    0.195         1.9485           0.9455
#
#        Viscera_weight     Shell_weight   Rings
# 0      Viscera_weight   Shell_weight\t   Rings
# ...

# %%
# Take a sample of the first 50 rows
df_sample = df.head(50)

# Chart 1: Scatter Plot of Abalone Length vs. Diameter
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sample, x='Length', y='Diameter', color='green')
plt.title('Abalone Length vs. Diameter (Sample)')
plt.xlabel('Length')
plt.ylabel('Diameter')
plt.grid(True)
plt.show()

# %%
# Chart 2: Distribution of Abalone by Sex (Sample)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sample, x='Diameter', y='Shell_weight', hue='Sex', palette=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Scatter Plot of Diameter vs. Shell Weight (Sample)')
plt.xlabel('Diameter')
plt.ylabel('Shell Weight')
plt.grid(True)
plt.show()
# Out:
# C:\Users\wrath\AppData\Local\Temp\ipykernel_43936\3000428291.py:3: UserWarning:
# The palette list has fewer values (3) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_sample, x='Diameter', y='Shell_weight', hue='Sex', palette=['skyblue', 'lightcoral', 'lightgreen'])
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Convert columns to numeric, replacing non-numeric values with NaN
df_sample['Diameter'] = pd.to_numeric(df_sample['Diameter'], errors='coerce')
df_sample['Shell_weight'] = pd.to_numeric(df_sample['Shell_weight'], errors='coerce')


# Chart 3 Plotting the boxplot for Diameter and Shell_weight with hue as Sex
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_sample, x='Diameter', y='Shell_weight', hue='Sex', palette=['skyblue', 'lightcoral', 'lightgreen'])
plt.xlabel('Diameter')
plt.ylabel('Shell Weight')
plt.title('Box Plot of Diameter vs Shell Weight by Sex (Sample)')
plt.show()
# Out:
# C:\Users\wrath\AppData\Local\Temp\ipykernel_43936\3197357711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['Diameter'] = pd.to_numeric(df_sample['Diameter'], errors='coerce')
# C:\Users\wrath\AppData\Local\Temp\ipykernel_43936\3197357711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['Shell_weight'] = pd.to_numeric(df_sample['Shell_weight'], errors='coerce')
